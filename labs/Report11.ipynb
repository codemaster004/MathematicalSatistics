# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.api import tools
from statsmodels.formula.api import ols
import scipy

# %%
df = pd.read_csv('../data/HR.csv')
df
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      NaN       Yes      Travel_Rarely       1102                   Sales
# 1     49.0        No  Travel_Frequently        279  Research & Development
# 2     37.0       NaN      Travel_Rarely       1373  Research & Development
# 3     33.0        No  Travel_Frequently       1392  Research & Development
# 4     27.0        No      Travel_Rarely        591  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1465  36.0        No  Travel_Frequently        884  Research & Development
# 1466  39.0        No      Travel_Rarely        613  Research & Development
# 1467  27.0        No      Travel_Rarely        155  Research & Development
# 1468  49.0        No  Travel_Frequently       1023                   Sales
# 1469  34.0        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df = df.dropna()

df['MonthlyIncomeTrans'], _, _ = stats.boxcox(df['MonthlyIncome'], alpha=0.01)

# Q-Q plot for Panek ratings
plt.figure(figsize=(10, 6))
stats.probplot(df['MonthlyIncomeTrans'], dist=stats.norm, plot=plt)
plt.title("Q-Q Plot for Panek Ratings")
plt.show()

shapiro = stats.shapiro(df['MonthlyIncomeTrans'])
print(f"Result of Shapiro-Wilk test: {shapiro}")
# Out:
# Result of Shapiro-Wilk test: ShapiroResult(statistic=0.9760816693305969, pvalue=1.5436434682575273e-12)

# %%
print(df.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'MonthlyIncomeTrans'],
#       dtype='object')

# %%
# Perform two-way ANOVA
model = ols('MonthlyIncomeTrans ~ OverTime', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Display the ANOVA results
print(anova_table)
# Out:
#             sum_sq      df         F    PR(>F)
# OverTime  0.000039     1.0  0.004954  0.943903
# Residual  8.616219  1103.0       NaN       NaN
